# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Creating a Multi-feature Dataset
data ={
    "Square_Feet":[1000,1500,1800,2400,3000,3500],
    "Bedrooms":[2,3,3,4,4,5],
    "Bathroom":[1,2,2,3,3,4],
    "Price":[50000,70000,80000,110000,150000,180000]
}
df = pd.DataFrame(data)

# %%
#Difinning the features X and Y
X = df[["Square_Feet","Bedrooms","Bathroom"]]
Y = df["Price"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
#Training Linear Model
model = LinearRegression()#Creating the LR model
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
#Prediction
y_pred = model.predict(X_test)

# %%
#Evaluating model performance
mse = mean_squared_error(Y_test, y_pred)
r2 = r2_score(Y_test, y_pred)
print("MEAN SQUARED ERROR:", mse)
print("R2_SCORE:", r2)
# Out:
# MEAN SQUARED ERROR: 233111277.9133051
# R2_SCORE: -1.331112779133051

# %%
#Vizualizing model profile
coefficient = model.coef_
features = X.columns
plt.bar(features, coefficient, color='darkblue')
plt.title("Feature Importance")
plt.ylabel("Coefficient Value")
plt.show()

plt.scatter(Y_test,y_pred, color='blue')
plt.plot([min(Y_test),max(Y_test)], [min(Y_test),max(Y_test)], color="red")
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Price")
plt.show()
